# %%
import matplotlib.pyplot as plt

# %%
plt.plot([[0,0],[1,1]], linewidth=4, label='random diagonal')
plt.show()

# %%
plt.plot([[0,0],[2,1]], linewidth=4, label='random diagonal')
plt.show()

# %%
print('result is:', 2+2)
# Out:
# result is: 4
